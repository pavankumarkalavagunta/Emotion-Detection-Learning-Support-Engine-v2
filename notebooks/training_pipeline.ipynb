# %%
# Load dataset from Hugging Face
print("Loading dair-ai/emotion dataset...")
dataset = load_dataset('dair-ai/emotion')

print(f"\nDataset splits: {dataset.keys()}")
print(f"Training samples: {len(dataset['train'])}")
print(f"Validation samples: {len(dataset['validation'])}")
print(f"Test samples: {len(dataset['test'])}")

# Explore dataset
print("\nDataset structure:")
print(dataset['train'][0])

# Check emotion distribution
train_emotions = dataset['train']['label']
emotion_counts = pd.Series(train_emotions).value_counts()
print(f"\nEmotion distribution in training set:")
print(emotion_counts)

# Map label indices to emotion names
EMOTION_NAMES = ['sadness', 'joy', 'love', 'anger', 'fear', 'surprise']
print(f"\nEmotion classes: {EMOTION_NAMES}")

# %% [markdown]
# ## Section 2: Data Loading and Exploration
#
# Load the dair-ai/emotion dataset from Hugging Face.

# %%
# Installation (run once)
# !pip install tensorflow torch transformers datasets scikit-learn pandas numpy streamlit plotly sentencepiece accelerate joblib
# !pip install -q datasets huggingface-hub

import os
import sys
import warnings
import json
import pickle
import numpy as np
import pandas as pd
from pathlib import Path
from typing import Tuple, Dict, List, Any

warnings.filterwarnings('ignore')

# TensorFlow and PyTorch imports
import tensorflow as tf
from tensorflow.keras import layers, models, callbacks
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report

import torch
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from datasets import load_dataset, DatasetDict, Dataset

print(f"TensorFlow version: {tf.__version__}")
print(f"PyTorch version: {torch.__version__}")
print(f"GPU Available: {torch.cuda.is_available()}")
print(f"GPU Device: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'CPU'}")

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
torch.manual_seed(42)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(42)

# %% [markdown]
# ## Section 1: Setup and Environment Configuration
#
# Install required dependencies and configure GPU settings.

# %% [markdown]
# # Emotion Detection Model Training Pipeline
# ## Complete Setup Guide for BiLSTM and BERT Models
#
# This notebook provides a comprehensive guide to:
# - Load the dair-ai/emotion dataset
# - Implement preprocessing pipelines
# - Train a BiLSTM emotion classifier
# - Fine-tune BERT for emotion classification
# - Evaluate and compare both models
# - Create production-ready predictor classes
# - Integrate into Streamlit application
#
# **Emotion Classes:** Happy, Sad, Angry, Fear, Surprise, Love, Neutral
